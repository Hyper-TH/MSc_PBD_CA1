# %% [markdown]
# # Twila Habab - C20361521
# ## TU059/FT ASD
# ### Programming for Big Data PROG9813

# %%
# Links
# Kaggle Competition: https://www.kaggle.com/competitions/playground-series-s4e6/data
# UCI: https://archive.ics.uci.edu/dataset/697/predict+students+dropout+and+academic+success
# DOI: 10.24432/C5MC89

# %%
# Curl the datasets from Kaggle from my GitHub, no need for Kaggle APIs

# %%
# %mkdir datasets
# Out:
# mkdir: cannot create directory ‘datasets’: File exists

# %%
# !curl -sSL https://raw.githubusercontent.com/Hyper-TH/datasets_for_pbd_ca/refs/heads/master/train.csv -o "datasets/train.csv"

# %%
# !curl -sSL https://raw.githubusercontent.com/Hyper-TH/datasets_for_pbd_ca/refs/heads/master/test.csv -o "datasets/test.csv"

# %%
# Import the necessary pyspark functions
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import StringIndexer, OneHotEncoder
from pyspark.ml import Pipeline
from pyspark.sql.functions import col
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# %%
# spark.stop()

# %%
# Set up Session
from pyspark.sql import SparkSession

spark = SparkSession.builder \
        .appName('C20361521 - Assignment 1') \
        .master('local[*]') \
        .getOrCreate()

# %%
# Load both datasets into DFs
train_file_path = 'datasets/train.csv'

dataset = spark.read.format("csv").option("header", "true")\
    .option("inferSchema", "true")\
    .load(train_file_path)

train_df, test_df = dataset.randomSplit([0.7,0.3], seed=42)

# %%
# Cache it with a count operation
print('Training set size = ', train_df.cache().count())
print('Testing set size = ', test_df.cache().count())

# train_df.show(5)
# test_df.show(5)
# Out:
# Training set size =  53814
# Testing set size =  22704

# %%
# Check schema
train_df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Marital status: integer (nullable = true)
#  |-- Application mode: integer (nullable = true)
#  |-- Application order: integer (nullable = true)
#  |-- Course: integer (nullable = true)
#  |-- Daytime/evening attendance: integer (nullable = true)
#  |-- Previous qualification: integer (nullable = true)
#  |-- Previous qualification (grade): double (nullable = true)
#  |-- Nacionality: integer (nullable = true)
#  |-- Mother's qualification: integer (nullable = true)
#  |-- Father's qualification: integer (nullable = true)
#  |-- Mother's occupation: integer (nullable = true)
#  |-- Father's occupation: integer (nullable = true)
#  |-- Admission grade: double (nullable = true)
#  |-- Displaced: integer (nullable = true)
#  |-- Educational special needs: integer (nullable = true)
#  |-- Debtor: integer (nullable = true)
#  |-- Tuition fees up to date: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Scholarship holder: integer (nullable = true)
#  |-- Age at enrollment: integer (nullable = true)
#  |-- International: integer (nullable = true)
#  |-- Curricular units 1st sem (credited): integer (nullable = true)
#  |-- Curricular units 1st sem (enrolled): integer (nullable = true)
#  |-- Curricular units 1st sem (evaluations): integer (nullable = true)
#  |-- Curricular units 1st sem (approved): integer (nullable = true)
#  |-- Curricular units 1st sem (grade): double (nullable = true)
#  |-- Curricular units 1st sem (without evaluations): integer (nullable = true)
#  |-- Curricular units 2nd sem (credited): integer (nullable = true)
#  |-- Curricular units 2nd sem (enrolled): integer (nullable = true)
#  |-- Curricular units 2nd sem (evaluations): integer (nullable = true)
#  |-- Curricular units 2nd sem (approved): integer (nullable = true)
#  |-- Curricular units 2nd sem (grade): double (nullable = true)
#  |-- Curricular units 2nd sem (without evaluations): integer (nullable = true)
#  |-- Unemployment rate: double (nullable = true)
#  |-- Inflation rate: double (nullable = true)
#  |-- GDP: double (nullable = true)
#  |-- Target: string (nullable = true)

# %%
test_df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- Marital status: integer (nullable = true)
#  |-- Application mode: integer (nullable = true)
#  |-- Application order: integer (nullable = true)
#  |-- Course: integer (nullable = true)
#  |-- Daytime/evening attendance: integer (nullable = true)
#  |-- Previous qualification: integer (nullable = true)
#  |-- Previous qualification (grade): double (nullable = true)
#  |-- Nacionality: integer (nullable = true)
#  |-- Mother's qualification: integer (nullable = true)
#  |-- Father's qualification: integer (nullable = true)
#  |-- Mother's occupation: integer (nullable = true)
#  |-- Father's occupation: integer (nullable = true)
#  |-- Admission grade: double (nullable = true)
#  |-- Displaced: integer (nullable = true)
#  |-- Educational special needs: integer (nullable = true)
#  |-- Debtor: integer (nullable = true)
#  |-- Tuition fees up to date: integer (nullable = true)
#  |-- Gender: integer (nullable = true)
#  |-- Scholarship holder: integer (nullable = true)
#  |-- Age at enrollment: integer (nullable = true)
#  |-- International: integer (nullable = true)
#  |-- Curricular units 1st sem (credited): integer (nullable = true)
#  |-- Curricular units 1st sem (enrolled): integer (nullable = true)
#  |-- Curricular units 1st sem (evaluations): integer (nullable = true)
#  |-- Curricular units 1st sem (approved): integer (nullable = true)
#  |-- Curricular units 1st sem (grade): double (nullable = true)
#  |-- Curricular units 1st sem (without evaluations): integer (nullable = true)
#  |-- Curricular units 2nd sem (credited): integer (nullable = true)
#  |-- Curricular units 2nd sem (enrolled): integer (nullable = true)
#  |-- Curricular units 2nd sem (evaluations): integer (nullable = true)
#  |-- Curricular units 2nd sem (approved): integer (nullable = true)
#  |-- Curricular units 2nd sem (grade): double (nullable = true)
#  |-- Curricular units 2nd sem (without evaluations): integer (nullable = true)
#  |-- Unemployment rate: double (nullable = true)
#  |-- Inflation rate: double (nullable = true)
#  |-- GDP: double (nullable = true)
#  |-- Target: string (nullable = true)

# %% [markdown]
# ## Data Exploration

# %%
# Check the summary of the Age at enrollment column
train_df.select("Age at enrollment").summary().show()
test_df.select("Age at enrollment").summary().show()

## Same quarters, min and max
# Out:
# +-------+-----------------+
# |summary|Age at enrollment|
# +-------+-----------------+
# |  count|            53814|
# |   mean| 22.2837179916007|
# | stddev|6.893586283991445|
# |    min|               17|
# |    25%|               18|
# |    50%|               19|
# |    75%|               23|
# |    max|               70|
# +-------+-----------------+
#
# +-------+------------------+
# |summary| Age at enrollment|
# +-------+------------------+
# |  count|             22704|
# |   mean|22.266649048625794|
# | stddev|  6.87906785361406|
# |    min|                17|
# |    25%|                18|
# |    50%|                19|
# |    75%|                23|
# |    max|                70|
# +-------+------------------+

# %%
# AGE GROUP COLUMN
# Since we know the min max of ages, we can group them
# min = 17; max = 70
# 17-24; 25-34; 35-44; 45-54; 55-64; 65-70;

# Creating a new column and inserting values with nested whens
train_df = train_df.withColumn("Age_Group",
    when(col("Age at enrollment") <= 24, "17-24")\
    .when(col("Age at enrollment") <= 34, "25-34")\
    .when(col("Age at enrollment") <= 44, "35-44")\
    .when(col("Age at enrollment") <= 54, "45-54")\
    .when(col("Age at enrollment") <= 64, "55-64")\
    .when(col("Age at enrollment") <= 70, "65-70")
)

# Do the same for test_df
test_df = test_df.withColumn("Age_Group",
    when(col("Age at enrollment") <= 24, "17-24")\
    .when(col("Age at enrollment") <= 34, "25-34")\
    .when(col("Age at enrollment") <= 44, "35-44")\
    .when(col("Age at enrollment") <= 54, "45-54")\
    .when(col("Age at enrollment") <= 64, "55-64")\
    .when(col("Age at enrollment") <= 70, "65-70")
)

train_df.select("Age_Group").distinct().show(n=train_df.count())
# Out:
# +---------+
# |Age_Group|
# +---------+
# |    45-54|
# |    55-64|
# |    17-24|
# |    35-44|
# |    25-34|
# |    65-70|
# +---------+

# %%
train_df.select("Age_Group")\
    .groupBy("Age_Group")\
    .agg(count("Age_Group").alias("Count"))\
    .orderBy("Count", ascending=False)\
    .show()

test_df.select("Age_Group")\
    .groupBy("Age_Group")\
    .agg(count("Age_Group").alias("Count"))\
    .orderBy("Count", ascending=False)\
    .show()
# Out:
# +---------+-----+
# |Age_Group|Count|
# +---------+-----+
# |    17-24|42240|
# |    25-34| 7535|
# |    35-44| 2774|
# |    45-54| 1123|
# |    55-64|  124|
# |    65-70|   18|
# +---------+-----+
#
# +---------+-----+
# |Age_Group|Count|
# +---------+-----+
# |    17-24|17921|
# |    25-34| 3068|
# |    35-44| 1153|
# |    45-54|  509|
# |    55-64|   51|
# |    65-70|    2|
# +---------+-----+

# %%
# Distribution of the Admission Grade
train_df.select("Admission grade").summary().show()
# Out:
# +-------+------------------+
# |summary|   Admission grade|
# +-------+------------------+
# |  count|             53814|
# |   mean|125.39263367803787|
# | stddev|  12.5955755773937|
# |    min|              95.0|
# |    25%|             118.0|
# |    50%|             124.7|
# |    75%|             132.0|
# |    max|             190.0|
# +-------+------------------+

# %%
# Distribution of Unemployment Rate
train_df.select("Unemployment rate").summary().show()
# Out:
# +-------+------------------+
# |summary| Unemployment rate|
# +-------+------------------+
# |  count|             53814|
# |   mean|11.521260266844916|
# | stddev| 2.655343651685822|
# |    min|               7.6|
# |    25%|               9.4|
# |    50%|              11.1|
# |    75%|              12.7|
# |    max|              16.2|
# +-------+------------------+

# %%
# Scholarship status
train_df.select(when(col("Scholarship holder") == 0, "No").otherwise("Yes").alias("Scholarship_Status")).groupBy("Scholarship_Status").count().show()
# Out:
# +------------------+-----+
# |Scholarship_Status|count|
# +------------------+-----+
# |                No|40591|
# |               Yes|13223|
# +------------------+-----+

# %%
# Will use TempView to explore and analyse the dataframes with SQL
train_df.createOrReplaceTempView("train_tab")
test_df.createOrReplaceTempView("test_tab")

# %%
# What is the most common qualification?
spark.sql(
    """SELECT `Previous Qualification`, count(*) AS COUNT FROM train_tab 
        GROUP BY `Previous Qualification` ORDER BY COUNT DESC"""
).show(train_df.count())
# Out:
# +----------------------+-----+
# |Previous Qualification|COUNT|
# +----------------------+-----+
# |                     1|47313|
# |                    19| 2049|
# |                    39| 2033|
# |                     3|  971|
# |                    12|  649|
# |                     9|  206|
# |                    40|  184|
# |                    42|  167|
# |                     6|   71|
# |                     2|   61|
# |                    10|   28|
# |                    38|   27|
# |                    43|   25|
# |                     4|   13|
# |                    15|    6|
# |                     5|    3|
# |                    37|    3|
# |                    14|    2|
# |                    17|    2|
# |                    36|    1|
# +----------------------+-----+

# %%
# Find the most common finished education by age_group
spark.sql("""
    SELECT `Previous Qualification` as Most_Common_Qualification, `Age_Group` AS Age
        FROM (
            SELECT `Previous Qualification`, `Age_Group`,
                RANK() OVER (PARTITION BY `Age_Group` ORDER BY cnt DESC) as rnk 
            FROM (
                SELECT `Previous Qualification`, `Age_Group`, COUNT(*) AS cnt
                FROM train_tab 
                GROUP BY `Previous Qualification`, `Age_Group`
            ) AS qual_count
        ) AS qual_rank_per_age
        WHERE rnk = 1 --get the top per group
    """).show(train_df.count())
# Out:
# +-------------------------+-----+
# |Most_Common_Qualification|  Age|
# +-------------------------+-----+
# |                        1|17-24|
# |                        1|25-34|
# |                        1|35-44|
# |                        1|45-54|
# |                       12|55-64|
# |                       19|65-70|
# +-------------------------+-----+

# %%
# Find the most common finished education by age_group
spark.sql("""
    SELECT `Previous Qualification` as Most_Common_Qualification, `Age at enrollment` AS Age
        FROM (
            SELECT `Previous Qualification`, `Age at enrollment`,
                RANK() OVER (PARTITION BY `Age at enrollment` ORDER BY cnt DESC) as rnk 
            FROM (
                SELECT `Previous Qualification`, `Age at enrollment`, COUNT(*) AS cnt
                FROM train_tab 
                GROUP BY `Previous Qualification`, `Age at enrollment`
            ) AS qual_count
        ) AS qual_rank_per_age
        WHERE rnk = 1
    """).show(train_df.count())
# Out:
# +-------------------------+---+
# |Most_Common_Qualification|Age|
# +-------------------------+---+
# |                        1| 17|
# |                        1| 18|
# |                        1| 19|
# |                        1| 20|
# |                        1| 21|
# |                        1| 22|
# |                        1| 23|
# |                        1| 24|
# |                        1| 25|
# |                        1| 26|
# |                        1| 27|
# |                        1| 28|
# |                        1| 29|
# |                        1| 30|
# |                        1| 31|
# |                        1| 32|
# |                        1| 33|
# |                        1| 34|
# |                        1| 35|
# |                        1| 36|
# |                        1| 37|
# |                        1| 38|
# |                        1| 39|
# |                        1| 40|
# |                        1| 41|
# |                        1| 42|
# |                        1| 43|
# |                        1| 44|
# |                        1| 45|
# |                        1| 46|
# |                        1| 47|
# |                       19| 48|
# |                        1| 49|
# |                        1| 50|
# |                        1| 51|
# |                        1| 52|
# |                       12| 52|
# |                        1| 53|
# |                        1| 54|
# |                       12| 55|
# |                        1| 57|
# |                       12| 58|
# |                        1| 59|
# |                       19| 60|
# |                        1| 61|
# |                       19| 62|
# |                       19| 70|
# +-------------------------+---+

# %%
# Find the most common coures per gender
spark.sql("""
    SELECT `Course` as Most_Common_Course, `Gender`
        FROM (
            SELECT `Course`, `Gender`,
                RANK() OVER (PARTITION BY `Gender` ORDER BY cnt DESC) as rnk 
            FROM (
                SELECT `Course`, `Gender`, COUNT(*) AS cnt
                FROM train_tab 
                GROUP BY `Course`, `Gender`
            ) AS course_count
        ) AS course_rank_per_age
        WHERE rnk = 1
    """).show(train_df.count())

# 0 (Female) => 9500 Nursing
# 1 (Male) => 9147 Management
# Out:
# +------------------+------+
# |Most_Common_Course|Gender|
# +------------------+------+
# |              9500|     0|
# |              9147|     1|
# +------------------+------+

# %% [markdown]
# ## Data Cleaning and Preparation

# %%
# Although the competition and the original source have stated
# that the datasets do not contain any NULL values, it is still
# good practice to check for any of it.

# %%
# TODO: Check any null values

# %%
## Sanity cleaning: rename columns for easier identification

train_df = train_df\
    .withColumnRenamed("Marital Status", "Marital_Status")\
    .withColumnRenamed("Application mode", "Application_Mode")\
    .withColumnRenamed("Application order", "Application_Order")\
    .withColumnRenamed("Daytime/evening attendance", "DayNight_Attendance")\
    .withColumnRenamed("Previous qualification", "Prev_Qualification")\
    .withColumnRenamed("Previous qualification (grade)", "Prev_Qualification_Grade")\
    .withColumnRenamed("Nacionality", "Nationality")\
    .withColumnRenamed("Mother's Qualification", "Mother_Qualification")\
    .withColumnRenamed("Father's Qualification", "Father_Qualification")\
    .withColumnRenamed("Mother's occupation", "Mother_Occupation")\
    .withColumnRenamed("Father's occupation", "Father_Occupation")\
    .withColumnRenamed("Admission grade", "Admission_Grade")\
    .withColumnRenamed("Educational special needs", "Special_Education")\
    .withColumnRenamed("Tuition fees up to date", "Up_To_Date_Tuition")\
    .withColumnRenamed("Scholarship holder", "Scholarship")\
    .withColumnRenamed("Age at enrollment", "Enrollment_Age")\
    .withColumnRenamed("Curricular units 1st sem (credited)", "1st_Sem_units_Credited")\
    .withColumnRenamed("Curricular units 1st sem (enrolled)", "1st_Sem_units_Enrolled")\
    .withColumnRenamed("Curricular units 1st sem (evaluations)", "1st_Sem_units_Evaluations")\
    .withColumnRenamed("Curricular units 1st sem (approved)", "1st_Sem_units_Approved")\
    .withColumnRenamed("Curricular units 1st sem (grade)", "1st_Sem_units_Grade")\
    .withColumnRenamed("Curricular units 1st sem (without evaluations)", "1st_Sem_units_NoEval")\
    .withColumnRenamed("Curricular units 2nd sem (credited)", "2nd_Sem_units_Credited")\
    .withColumnRenamed("Curricular units 2nd sem (enrolled)", "2nd_Sem_units_Enrolled")\
    .withColumnRenamed("Curricular units 2nd sem (evaluations)", "2nd_Sem_units_Evaluations")\
    .withColumnRenamed("Curricular units 2nd sem (approved)", "2nd_Sem_units_Approved")\
    .withColumnRenamed("Curricular units 2nd sem (grade)", "2nd_Sem_units_Grade")\
    .withColumnRenamed("Curricular units 2nd sem (without evaluations)", "2nd_Sem_units_NoEval")\
    .withColumnRenamed("Unemployment rate", "Unemployment_Rate")\
    .withColumnRenamed("Inflation rate", "Inflation_Rate")


# Do the same for test_df
test_df= test_df\
    .withColumnRenamed("Marital Status", "Marital_Status")\
    .withColumnRenamed("Application mode", "Application_Mode")\
    .withColumnRenamed("Application order", "Application_Order")\
    .withColumnRenamed("Daytime/evening attendance", "DayNight_Attendance")\
    .withColumnRenamed("Previous qualification", "Prev_Qualification")\
    .withColumnRenamed("Previous qualification (grade)", "Prev_Qualification_Grade")\
    .withColumnRenamed("Nacionality", "Nationality")\
    .withColumnRenamed("Mother's Qualification", "Mother_Qualification")\
    .withColumnRenamed("Father's Qualification", "Father_Qualification")\
    .withColumnRenamed("Mother's occupation", "Mother_Occupation")\
    .withColumnRenamed("Father's occupation", "Father_Occupation")\
    .withColumnRenamed("Admission grade", "Admission_Grade")\
    .withColumnRenamed("Educational special needs", "Special_Education")\
    .withColumnRenamed("Tuition fees up to date", "Up_To_Date_Tuition")\
    .withColumnRenamed("Scholarship holder", "Scholarship")\
    .withColumnRenamed("Age at enrollment", "Enrollment_Age")\
    .withColumnRenamed("Curricular units 1st sem (credited)", "1st_Sem_units_Credited")\
    .withColumnRenamed("Curricular units 1st sem (enrolled)", "1st_Sem_units_Enrolled")\
    .withColumnRenamed("Curricular units 1st sem (evaluations)", "1st_Sem_units_Evaluations")\
    .withColumnRenamed("Curricular units 1st sem (approved)", "1st_Sem_units_Approved")\
    .withColumnRenamed("Curricular units 1st sem (grade)", "1st_Sem_units_Grade")\
    .withColumnRenamed("Curricular units 1st sem (without evaluations)", "1st_Sem_units_NoEval")\
    .withColumnRenamed("Curricular units 2nd sem (credited)", "2nd_Sem_units_Credited")\
    .withColumnRenamed("Curricular units 2nd sem (enrolled)", "2nd_Sem_units_Enrolled")\
    .withColumnRenamed("Curricular units 2nd sem (evaluations)", "2nd_Sem_units_Evaluations")\
    .withColumnRenamed("Curricular units 2nd sem (approved)", "2nd_Sem_units_Approved")\
    .withColumnRenamed("Curricular units 2nd sem (grade)", "2nd_Sem_units_Grade")\
    .withColumnRenamed("Curricular units 2nd sem (without evaluations)", "2nd_Sem_units_NoEval")\
    .withColumnRenamed("Unemployment rate", "Unemployment_Rate")\
    .withColumnRenamed("Inflation rate", "Inflation_Rate")

# train_df.show(5)    
# test_df.show(5)

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ## Build a model that predicts the academic risk of students in higher education

# %%
# Because majority of the data is numerical and there are no strings, 
# need to find out which column can be categorized.

# CATEGORICAL CANDIDATES
# Marital status
# Gender
# Age of enrollment (needs categorization)
# Previous Qualification (needs categorization)

# %% [markdown]
# ### Convert Categorical Variables

# %%
# Cast the columns into string type so that it can be passed onto the string indexer
train_df = train_df\
    .withColumn("Marital_Status", col("Marital_Status").cast("string"))\
    .withColumn("Application_Mode", col("Application_Mode").cast("string"))\
    .withColumn("Application_Order", col("Application_Order").cast("string"))\
    .withColumn("Course", col("Course").cast("string"))\
    .withColumn("Prev_Qualification", col("Prev_Qualification").cast("string"))\
    .withColumn("Nationality", col("Nationality").cast("string"))\
    .withColumn("Mother_Qualification", col("Mother_Qualification").cast("string"))\
    .withColumn("Father_Qualification", col("Father_Qualification").cast("string"))\
    .withColumn("Mother_Occupation", col("Mother_Occupation").cast("string"))\
    .withColumn("Father_Occupation", col("Father_Occupation").cast("string"))\
    .withColumn("Age_Group", col("Age_Group").cast("string"))

test_df = test_df\
    .withColumn("Marital_Status", col("Marital_Status").cast("string"))\
    .withColumn("Application_Mode", col("Application_Mode").cast("string"))\
    .withColumn("Application_Order", col("Application_Order").cast("string"))\
    .withColumn("Course", col("Course").cast("string"))\
    .withColumn("Prev_Qualification", col("Prev_Qualification").cast("string"))\
    .withColumn("Nationality", col("Nationality").cast("string"))\
    .withColumn("Mother_Qualification", col("Mother_Qualification").cast("string"))\
    .withColumn("Father_Qualification", col("Father_Qualification").cast("string"))\
    .withColumn("Mother_Occupation", col("Mother_Occupation").cast("string"))\
    .withColumn("Father_Occupation", col("Father_Occupation").cast("string"))\
    .withColumn("Age_Group", col("Age_Group").cast("string"))

# %% [markdown]
# ### How about a big model?

# %%
# StringIndexer and OneHotEncoder

# Categorical Columns
categoricalCols = ["Marital_Status","Application_Mode","Application_Order",
                   "Course","Prev_Qualification","Nationality",
                   "Mother_Qualification", "Father_Qualification","Mother_Occupation",
                  "Father_Occupation"]

# Estimators, return functions that will later use for transforming the dataset.
# ESTIMATOR
stringIndexer = StringIndexer(inputCols=categoricalCols, outputCols=[x + "Index" for x in categoricalCols], handleInvalid="keep")
encoder = OneHotEncoder(inputCols=stringIndexer.getOutputCols(), outputCols=[x + "OHE" for x in categoricalCols])

# The label 'Target' is also a string value, convert it to numeric
labelToIndex = StringIndexer(inputCol="Target", outputCol="label")

# %%
# TRANSFORMER
stringIndexerModel = stringIndexer.fit(train_df)
stringIndexerModel.transform(train_df).select("Marital_Status", "Target").show(5, truncate=False)
# Out:
# +--------------+--------+
# |Marital_Status|Target  |
# +--------------+--------+
# |1             |Graduate|
# |1             |Dropout |
# |1             |Enrolled|
# |1             |Graduate|
# |1             |Dropout |
# +--------------+--------+
# only showing top 5 rows

# %%
# FEATURE VECTOR
numericCols = ["DayNight_Attendance", "Prev_Qualification_Grade", "Admission_Grade",
              "Displaced", "Special_Education", "Debtor",  "Up_To_Date_Tuition", 
              "Gender", "Scholarship", "Enrollment_Age", "International",
              "1st_Sem_units_Credited", "1st_Sem_units_Enrolled", "1st_Sem_units_Evaluations",
              "1st_Sem_units_Approved", "1st_Sem_units_Grade", "1st_Sem_units_NoEval",
              "2nd_Sem_units_Credited", "2nd_Sem_units_Enrolled", "2nd_Sem_units_Evaluations",
              "2nd_Sem_units_Approved", "2nd_Sem_units_Grade", "2nd_Sem_units_NoEval",
              "Unemployment_Rate", "Inflation_Rate", "GDP"]


assemblerInputs =[c + "OHE" for c in categoricalCols] + numericCols
vecAssembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")

# %% [markdown]
# ### Let's do Smaller Models

# %%
# GROUP 1: Demographic-based
# GROUP 2: Education-based
# GROUP 3: Financial-based

# TODO: redo the categoricalcols of the mini groups

# %%
# StringIndexer and OneHotEncoder

# Categorical Columns
categoricalCols_model1 = ["Marital_Status", "International", "Mother_Occupation", "Father_Occupation", "Unemployment_Rate", "Nationality"] # Demographic Features
categoricalCols_model2 = ["Application_Mode", "Application_Order", "Course",  "Prev_Qualification", "Mother_Qualification", "Father_Qualification", "Enrollment_Age",  "Scholarship", "Special_Education", "EnrollmentAge"] # Educational Features
categoricalCols_model3 = ["Mother_Occupation", "Father_Occupation"] # Financial Features

numericCols_1 = ["Gender", "Displaced", ] # Demographic Features
numericCols_2 = ["DayNight_Attendance", "Admission_Grade"] # Educational Features
numericCols_3 = ["Prev_Qualification_Grade", "Admission_Grade"] # Financial Features

# %%
# Estimators, return functions that will later use for transforming the dataset.
# ESTIMATOR 1
stringIndexer_1 = StringIndexer(inputCols=categoricalCols_model1, outputCols=[x + "Index" for x in categoricalCols_model1], handleInvalid="keep")
encoder_1 = OneHotEncoder(inputCols=stringIndexer_1.getOutputCols(), outputCols=[x + "OHE" for x in categoricalCols_model1])

# ESTIMATOR 2
stringIndexer_2 = StringIndexer(inputCols=categoricalCols_model2, outputCols=[x + "Index" for x in categoricalCols_model2], handleInvalid="keep")
encoder_2 = OneHotEncoder(inputCols=stringIndexer_2.getOutputCols(), outputCols=[x + "OHE" for x in categoricalCols_model2])

# ESTIMATOR 3
stringIndexer_3 = StringIndexer(inputCols=categoricalCols_model3, outputCols=[x + "Index" for x in categoricalCols_model3], handleInvalid="keep")
encoder_3 = OneHotEncoder(inputCols=stringIndexer_3.getOutputCols(), outputCols=[x + "OHE" for x in categoricalCols_model3])

# The label 'Target' is also a string value, convert it to numeric
labelToIndex = StringIndexer(inputCol="Target", outputCol="label")

# %%
# TRANSFORMER 1
stringIndexerModel_1 = stringIndexer_1.fit(train_df)
stringIndexerModel_1.transform(train_df).select("Marital_Status", "Gender", "International", "Target").show(5, truncate=False)

# TRANSFORMER 2
stringIndexerModel_2 = stringIndexer_2.fit(train_df)
stringIndexerModel_2.transform(train_df).select("Enrollment_Age", "Scholarship", "Special_Education", "Target").show(5, truncate=False)

# TRANSFORMER 3
stringIndexerModel_3 = stringIndexer_3.fit(train_df)
stringIndexerModel_3.transform(train_df).select("Enrollment_Age", "Scholarship", "Special_Education", "Target").show(5, truncate=False)
# Out:
# +--------------+------+-------------+--------+
# |Marital_Status|Gender|International|Target  |
# +--------------+------+-------------+--------+
# |1             |0     |0            |Graduate|
# |1             |0     |0            |Dropout |
# |1             |0     |0            |Enrolled|
# |1             |0     |0            |Graduate|
# |1             |1     |0            |Dropout |
# +--------------+------+-------------+--------+
# only showing top 5 rows
# +--------------+-----------+-----------------+--------+
# |Enrollment_Age|Scholarship|Special_Education|Target  |
# +--------------+-----------+-----------------+--------+
# |18            |1          |0                |Graduate|
# |18            |0          |0                |Dropout |
# |18            |1          |0                |Enrolled|
# |18            |0          |0                |Graduate|
# |24            |0          |0                |Dropout |
# +--------------+-----------+-----------------+--------+
# only showing top 5 rows

# %% [markdown]
# ### Combine all feature columns into a single feature vector

# %%
# FEATURE VECTOR 1
assemblerInputs_1 =[c + "OHE" for c in categoricalCols_model1]
vecAssembler_1 = VectorAssembler(inputCols=assemblerInputs_1, outputCol="features")

# FEATURE VECTOR 2
numericCols = ["Prev_Qualification_Grade", "Admission_Grade"]
assemblerInputs_2 =[c + "OHE" for c in categoricalCols_model2] + numericCols
vecAssembler_2 = VectorAssembler(inputCols=assemblerInputs_2, outputCol="features")

# FEATURE VECTOR 3
numericCols = ["Prev_Qualification_Grade", "Admission_Grade"]
assemblerInputs_2 =[c + "OHE" for c in categoricalCols_model2] + numericCols
vecAssembler_2 = VectorAssembler(inputCols=assemblerInputs_2, outputCol="features")

# %% [markdown]
# ### Models

# %%
# Model 1: Education Based
# Model 2: Family Based
# Model 3: Personal/Financial Based

# %%
# Define the model
lr = LogisticRegression(featuresCol="features", labelCol="label", regParam=1.0)

# %%
# Dataset was loaded with header=True, so no issues with the first data row

# Define the pipeline based on stages created in prev steps
pipeline = Pipeline(stages=[stringIndexer, encoder, labelToIndex, vecAssembler, lr])
pipeline_1 = Pipeline(stages=[stringIndexer_1, encoder_1, labelToIndex, vecAssembler_1, lr])
pipeline_2 = Pipeline(stages=[stringIndexer_2, encoder_2, labelToIndex, vecAssembler_2, lr])

# Define the pipeline model
pipelineModel = pipeline.fit(train_df)
pipelineModel_1 = pipeline_1.fit(train_df)
pipelineModel_2 = pipeline_2.fit(train_df)

# Apply the pipeline model to the test dataset
predDF = pipelineModel.transform(test_df)
predDF_1 = pipelineModel_1.transform(test_df)
predDF_2 = pipelineModel_2.transform(test_df)

# %%
# Display predictions from the main model
predDF.select("features", "label", "prediction", "probability").show(5)
# Out:
# +--------------------+-----+----------+--------------------+
# |            features|label|prediction|         probability|
# +--------------------+-----+----------+--------------------+
# |(280,[0,7,27,38,5...|  1.0|       1.0|[0.21459409479263...|
# |(280,[0,9,26,37,5...|  0.0|       0.0|[0.47569876060715...|
# |(280,[0,8,26,41,5...|  1.0|       1.0|[0.09067449533304...|
# |(280,[0,6,31,33,5...|  0.0|       0.0|[0.75725793932293...|
# |(280,[1,8,26,36,5...|  1.0|       1.0|[0.28641934423486...|
# +--------------------+-----+----------+--------------------+
# only showing top 5 rows

# %%
# Display predictions from the model 1
predDF_1.select("features", "label", "prediction", "probability").show(5)
# Out:
# +--------------------+-----+----------+--------------------+
# |            features|label|prediction|         probability|
# +--------------------+-----+----------+--------------------+
# |(31,[0,7,8,17,28]...|  1.0|       1.0|[0.36804196216839...|
# |(31,[0,6,8,13,24]...|  0.0|       0.0|[0.56374214405866...|
# |(31,[0,7,8,17,28]...|  1.0|       1.0|[0.36804196216839...|
# |(31,[0,6,8,10,21]...|  0.0|       0.0|[0.47858369165810...|
# |(31,[1,6,8,11,22]...|  1.0|       0.0|[0.41335551839271...|
# +--------------------+-----+----------+--------------------+
# only showing top 5 rows

# %%
# Display predictions from the model 2
predDF_2.select("features", "label", "prediction", "probability").show(5)
# Out:
# +--------------------+-----+----------+--------------------+
# |            features|label|prediction|         probability|
# +--------------------+-----+----------+--------------------+
# |(70,[0,51,64,66,6...|  1.0|       0.0|[0.48563292699055...|
# |(70,[3,50,64,66,6...|  0.0|       0.0|[0.40995167001300...|
# |(70,[5,54,64,66,6...|  1.0|       1.0|[0.34656057475597...|
# |(70,[0,46,65,66,6...|  0.0|       0.0|[0.71944604768582...|
# |(70,[12,49,64,66,...|  1.0|       1.0|[0.32799209318149...|
# +--------------------+-----+----------+--------------------+
# only showing top 5 rows

# %%
# pipelineModel.stages[-1], predDf.drop("prediction", "rawPrediction", "probability").show()
pipelineModel.stages[-1], predDF.select("rawPrediction").show(2, truncate=False)
# Out:
# +-------------------------------------------------------------+
# |rawPrediction                                                |
# +-------------------------------------------------------------+
# |[-0.21926901821154154,0.8862835167806137,-0.6670144985690658]|
# |[0.398580850821743,-0.26264723130324286,-0.1359336195184952] |
# +-------------------------------------------------------------+
# only showing top 2 rows
# (LogisticRegressionModel: uid=LogisticRegression_eacf245855d5, numClasses=3, numFeatures=280,
#  None)

# %%
# pipelineModel.stages[-1], predDf.drop("prediction", "rawPrediction", "probability").show()
pipelineModel_1.stages[-1], predDF_1.select("rawPrediction").show(2, truncate=False)
# Out:
# +-------------------------------------------------------------+
# |rawPrediction                                                |
# +-------------------------------------------------------------+
# |[0.15690830714855397,0.3342297232876735,-0.4911380304362355] |
# |[0.6405688922572672,-0.16938292993274817,-0.4711859623245304]|
# +-------------------------------------------------------------+
# only showing top 2 rows
# (LogisticRegressionModel: uid=LogisticRegression_eacf245855d5, numClasses=3, numFeatures=31,
#  None)

# %%
# pipelineModel.stages[-1], predDf.drop("prediction", "rawPrediction", "probability").show()
pipelineModel_2.stages[-1], predDF_2.select("rawPrediction").show(2, truncate=False)
# Out:
# +--------------------------------------------------------------+
# |rawPrediction                                                 |
# +--------------------------------------------------------------+
# |[0.4365999131335636,-0.021523571916219342,-0.4150763412173425]|
# |[0.23622581261551368,0.10803640999886865,-0.3442622226143808] |
# +--------------------------------------------------------------+
# only showing top 2 rows
# (LogisticRegressionModel: uid=LogisticRegression_eacf245855d5, numClasses=3, numFeatures=70,
#  None)

# %%
# Evaluate the models
mcEvaluator = MulticlassClassificationEvaluator(metricName="accuracy")
print(f"Accuracy of main model: {mcEvaluator.evaluate(predDF)}")
print(f"Accuracy of model 1: {mcEvaluator.evaluate(predDF_1)}")
print(f"Accuracy of model 2: {mcEvaluator.evaluate(predDF_2)}")
# Out:
# Accuracy of main model: 0.7325140944326991
# Accuracy of model 1: 0.5616190979563073
# Accuracy of model 2: 0.6231501057082452

# %%
# Need to investigate..

spark.sql("""SELECT count(Target) FROM train_tab GROUP BY Target""").show()
# Out:
# +-------------+
# |count(Target)|
# +-------------+
# |        10491|
# |        17858|
# |        25465|
# +-------------+

# %% [markdown]
# ### HyperParameter (HP) Tuning

# %%
paramGrid = (ParamGridBuilder()
             .addGrid(lr.regParam, [0.1, 0.5, 2.0])
             .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])
             .build())

# %%
# Create a 3-fold CrossValidator for model 1
cv = CrossValidator(estimator=pipeline, estimatorParamMaps=paramGrid, evaluator=mcEvaluator, numFolds=3, parallelism=4)

# Run cross validations. This may take a while and returns the best model found 
cvModel = cv.fit(train_df)

# %%
# Create a 3-fold CrossValidator for model 1
cv_1 = CrossValidator(estimator=pipeline_1, estimatorParamMaps=paramGrid, evaluator=mcEvaluator, numFolds=3, parallelism=4)

# Run cross validations. This may take a while and returns the best model found 
cvModel_1 = cv_1.fit(train_df)

# %%
# Create a 3-fold CrossValidator for model1
cv_2 = CrossValidator(estimator=pipeline_2, estimatorParamMaps=paramGrid, evaluator=mcEvaluator, numFolds=3, parallelism=4)

# Run cross validations. This may take a while and returns the best model found 
cvModel_2 = cv_2.fit(train_df)

# %%
# Evaluate the models
cvPredDF = cvModel.transform(test_df)
cvPredDF_1 = cvModel_1.transform(test_df)
cvPredDF_2 = cvModel_2.transform(test_df)

print(f"Accuracy for main model: {mcEvaluator.evaluate(cvPredDF)}")
print(f"Accuracy for model 1: {mcEvaluator.evaluate(cvPredDF_1)}")
print(f"Accuracy for model 2: {mcEvaluator.evaluate(cvPredDF_2)}")
# Out:
# Accuracy for main model: 0.8061575052854123
# Accuracy for model 1: 0.5711328400281889
# Accuracy for model 2: 0.6501057082452432
